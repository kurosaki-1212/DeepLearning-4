# %%
# MLPでfetch_olivetti_facesの分類問題に挑戦
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
# ×:from keras.optimizers import RMSprop
from tensorflow.keras.optimizers import RMSprop
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# 入力と出力を指定
in_size = 64 * 64
out_size = 40

# fetch_olivetti_facesデータセットを読み込む
faces = datasets.fetch_olivetti_faces()

X = faces.data
y = faces.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# データを64*64=4096の一次元配列に変換
X_train = X_train.reshape(-1, 4096).astype('float32') / 255
X_test = X_test.reshape(-1, 4096).astype('float32') / 255

# データのOneHotエンコーディング
from tensorflow.keras import utils as np_utils

y_train = np_utils.to_categorical(y_train.astype('int32'))
y_test = np_utils.to_categorical(y_test.astype('int32'))


# MLPモデル構造を定義
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(in_size,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(out_size, activation='softmax'))

# モデルをコンパイル
model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(),
    metrics=['accuracy'])

# 学習を実行
hist = model.fit(X_train, y_train,
          batch_size=20, 
          epochs=60,
          verbose=1,
          validation_data=(X_test, y_test))

# モデルを評価
score = model.evaluate(X_test, y_test, verbose=1)
print('正解率=', score[1], 'loss=', score[0])

# 学習の様子をグラフへ描画
# 正解率の推移をプロット
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# ロスの推移をプロット
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/60
# 16/16 [==============================] - 2s 42ms/step - loss: 3.7022 - accuracy: 0.0219 - val_loss: 3.6993 - val_accuracy: 0.0000e+00
# Epoch 2/60
# 16/16 [==============================] - 1s 34ms/step - loss: 3.6896 - accuracy: 0.0312 - val_loss: 3.7066 - val_accuracy: 0.0000e+00
# Epoch 3/60
# 16/16 [==============================] - 1s 32ms/step - loss: 3.6879 - accuracy: 0.0219 - val_loss: 3.7154 - val_accuracy: 0.0000e+00
# Epoch 4/60
# 16/16 [==============================] - 1s 32ms/step - loss: 3.6850 - accuracy: 0.0219 - val_loss: 3.7297 - val_accuracy: 0.0000e+00
# Epoch 5/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.6835 - accuracy: 0.0188 - val_loss: 3.7403 - val_accuracy: 0.0000e+00
# Epoch 6/60
# 16/16 [==============================] - 1s 32ms/step - loss: 3.6818 - accuracy: 0.0312 - val_loss: 3.7509 - val_accuracy: 0.0000e+00
# Epoch 7/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.6796 - accuracy: 0.0250 - val_loss: 3.7548 - val_accuracy: 0.0000e+00
# Epoch 8/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.6753 - accuracy: 0.0406 - val_loss: 3.7648 - val_accuracy: 0.0000e+00
# Epoch 9/60
# 16/16 [==============================] - 1s 34ms/step - loss: 3.6737 - accuracy: 0.0375 - val_loss: 3.7700 - val_accuracy: 0.0000e+00
# Epoch 10/60
# 16/16 [==============================] - 0s 31ms/step - loss: 3.6698 - accuracy: 0.0344 - val_loss: 3.7645 - val_accuracy: 0.0000e+00
# Epoch 11/60
# 16/16 [==============================] - 1s 34ms/step - loss: 3.6639 - accuracy: 0.0344 - val_loss: 3.7553 - val_accuracy: 0.0000e+00
# Epoch 12/60
# 16/16 [==============================] - 1s 32ms/step - loss: 3.6570 - accuracy: 0.0500 - val_loss: 3.7619 - val_accuracy: 0.0000e+00
# Epoch 13/60
# 16/16 [==============================] - 1s 35ms/step - loss: 3.6481 - accuracy: 0.0344 - val_loss: 3.7482 - val_accuracy: 0.0000e+00
# Epoch 14/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.6383 - accuracy: 0.0375 - val_loss: 3.7379 - val_accuracy: 0.0000e+00
# Epoch 15/60
# 16/16 [==============================] - 1s 39ms/step - loss: 3.6214 - accuracy: 0.0500 - val_loss: 3.7426 - val_accuracy: 0.0000e+00
# Epoch 16/60
# 16/16 [==============================] - 1s 34ms/step - loss: 3.5962 - accuracy: 0.0500 - val_loss: 3.7317 - val_accuracy: 0.0000e+00
# Epoch 17/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.5725 - accuracy: 0.0562 - val_loss: 3.7094 - val_accuracy: 0.0000e+00
# Epoch 18/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.5420 - accuracy: 0.0562 - val_loss: 3.6861 - val_accuracy: 0.0000e+00
# Epoch 19/60
# 16/16 [==============================] - 1s 34ms/step - loss: 3.5137 - accuracy: 0.0625 - val_loss: 3.6629 - val_accuracy: 0.0000e+00
# Epoch 20/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.4677 - accuracy: 0.0781 - val_loss: 3.6269 - val_accuracy: 0.0375
# Epoch 21/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.4212 - accuracy: 0.0906 - val_loss: 3.6060 - val_accuracy: 0.0125
# Epoch 22/60
# 16/16 [==============================] - 1s 34ms/step - loss: 3.3614 - accuracy: 0.1250 - val_loss: 3.5733 - val_accuracy: 0.0625
# Epoch 23/60
# 16/16 [==============================] - 1s 34ms/step - loss: 3.3186 - accuracy: 0.1531 - val_loss: 3.5376 - val_accuracy: 0.0500
# Epoch 24/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.2626 - accuracy: 0.1562 - val_loss: 3.4772 - val_accuracy: 0.0875
# Epoch 25/60
# 16/16 [==============================] - 1s 32ms/step - loss: 3.2229 - accuracy: 0.1937 - val_loss: 3.4183 - val_accuracy: 0.0875
# Epoch 26/60
# 16/16 [==============================] - 1s 32ms/step - loss: 3.1544 - accuracy: 0.2000 - val_loss: 3.3726 - val_accuracy: 0.0625
# Epoch 27/60
# 16/16 [==============================] - 1s 33ms/step - loss: 3.0837 - accuracy: 0.1969 - val_loss: 3.3298 - val_accuracy: 0.0875
# Epoch 28/60
# 16/16 [==============================] - 1s 32ms/step - loss: 3.0372 - accuracy: 0.2156 - val_loss: 3.2883 - val_accuracy: 0.1000
# Epoch 29/60
# 16/16 [==============================] - 0s 31ms/step - loss: 2.9505 - accuracy: 0.2188 - val_loss: 3.2288 - val_accuracy: 0.0875
# Epoch 30/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.9173 - accuracy: 0.2469 - val_loss: 3.1496 - val_accuracy: 0.1125
# Epoch 31/60
# 16/16 [==============================] - 1s 32ms/step - loss: 2.8784 - accuracy: 0.2313 - val_loss: 3.1478 - val_accuracy: 0.1250
# Epoch 32/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.8157 - accuracy: 0.2594 - val_loss: 3.0312 - val_accuracy: 0.1625
# Epoch 33/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.7257 - accuracy: 0.2969 - val_loss: 3.0400 - val_accuracy: 0.1500
# Epoch 34/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.6840 - accuracy: 0.2844 - val_loss: 2.9482 - val_accuracy: 0.1375
# Epoch 35/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.6395 - accuracy: 0.2906 - val_loss: 2.9180 - val_accuracy: 0.1625
# Epoch 36/60
# 16/16 [==============================] - 1s 32ms/step - loss: 2.5898 - accuracy: 0.2875 - val_loss: 2.8573 - val_accuracy: 0.1750
# Epoch 37/60
# 16/16 [==============================] - 0s 31ms/step - loss: 2.5404 - accuracy: 0.2688 - val_loss: 2.7735 - val_accuracy: 0.2250
# Epoch 38/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.4815 - accuracy: 0.3281 - val_loss: 2.7419 - val_accuracy: 0.2000
# Epoch 39/60
# 16/16 [==============================] - 1s 32ms/step - loss: 2.4277 - accuracy: 0.3219 - val_loss: 2.7208 - val_accuracy: 0.2625
# Epoch 40/60
# 16/16 [==============================] - 1s 32ms/step - loss: 2.3757 - accuracy: 0.3281 - val_loss: 2.6928 - val_accuracy: 0.2625
# Epoch 41/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.3483 - accuracy: 0.3063 - val_loss: 2.6071 - val_accuracy: 0.2750
# Epoch 42/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.3082 - accuracy: 0.3375 - val_loss: 2.5691 - val_accuracy: 0.3125
# Epoch 43/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.2962 - accuracy: 0.3656 - val_loss: 2.5283 - val_accuracy: 0.3000
# Epoch 44/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.2433 - accuracy: 0.3531 - val_loss: 2.4899 - val_accuracy: 0.3625
# Epoch 45/60
# 16/16 [==============================] - 1s 35ms/step - loss: 2.2118 - accuracy: 0.3719 - val_loss: 2.5037 - val_accuracy: 0.3000
# Epoch 46/60
# 16/16 [==============================] - 1s 34ms/step - loss: 2.1838 - accuracy: 0.3781 - val_loss: 2.4883 - val_accuracy: 0.3375
# Epoch 47/60
# 16/16 [==============================] - 1s 32ms/step - loss: 2.1485 - accuracy: 0.3719 - val_loss: 2.4148 - val_accuracy: 0.3875
# Epoch 48/60
# 16/16 [==============================] - 1s 34ms/step - loss: 2.1322 - accuracy: 0.3594 - val_loss: 2.4106 - val_accuracy: 0.3625
# Epoch 49/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.1297 - accuracy: 0.3906 - val_loss: 2.4079 - val_accuracy: 0.3500
# Epoch 50/60
# 16/16 [==============================] - 1s 34ms/step - loss: 2.0694 - accuracy: 0.4000 - val_loss: 2.3328 - val_accuracy: 0.3875
# Epoch 51/60
# 16/16 [==============================] - 1s 33ms/step - loss: 2.0835 - accuracy: 0.3844 - val_loss: 2.2976 - val_accuracy: 0.3750
# Epoch 52/60
# 16/16 [==============================] - 1s 34ms/step - loss: 2.0157 - accuracy: 0.3938 - val_loss: 2.2990 - val_accuracy: 0.3750
# Epoch 53/60
# 16/16 [==============================] - 1s 32ms/step - loss: 2.0167 - accuracy: 0.4156 - val_loss: 2.3328 - val_accuracy: 0.3375
# Epoch 54/60
# 16/16 [==============================] - 1s 36ms/step - loss: 1.9776 - accuracy: 0.4250 - val_loss: 2.2741 - val_accuracy: 0.3625
# Epoch 55/60
# 16/16 [==============================] - 1s 32ms/step - loss: 1.9469 - accuracy: 0.4125 - val_loss: 2.2474 - val_accuracy: 0.4250
# Epoch 56/60
# 16/16 [==============================] - 1s 33ms/step - loss: 1.9778 - accuracy: 0.4000 - val_loss: 2.2401 - val_accuracy: 0.3625
# Epoch 57/60
# 16/16 [==============================] - 1s 33ms/step - loss: 1.9614 - accuracy: 0.4156 - val_loss: 2.1708 - val_accuracy: 0.4750
# Epoch 58/60
# 16/16 [==============================] - 1s 34ms/step - loss: 1.9070 - accuracy: 0.4375 - val_loss: 2.1977 - val_accuracy: 0.4125
# Epoch 59/60
# 16/16 [==============================] - 1s 35ms/step - loss: 1.9018 - accuracy: 0.4125 - val_loss: 2.1713 - val_accuracy: 0.4250
# Epoch 60/60
# 16/16 [==============================] - 1s 34ms/step - loss: 1.8245 - accuracy: 0.4688 - val_loss: 2.2143 - val_accuracy: 0.4375
# 3/3 [==============================] - 0s 10ms/step - loss: 2.2143 - accuracy: 0.4375
# 正解率= 0.4375 loss= 2.21427583694458
